# %% [markdown]
# ### jsonファイルの編集

# %%
# テキストを形態素分析してくれる
import MeCab
# 自然言語処理用ライブラリ・単語のベクトル表現を獲得する
import gensim
from collections import Counter
import re
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./meta.json", delimiter = "\n", header=None)

# %%
tag = []
for i in df.index:
    meta = json.loads(df.iloc[i].values[0])
    meta['tags']
    tag.append(meta['tags'])

# %%
str_tag = str(tag)

# %%
tag_change = str_tag.replace(',','').replace('[','').replace(']','').replace("'","").replace(' ','\n')

# %%
mecab = MeCab.Tagger("-Owakati -d /usr/local/lib/mecab/dic/mecab-ipadic-neologd/")
t = mecab.parse(tag_change)

# %%
t1 = t.lower().replace(' / ','/').replace('-','')
t2 = list(t1)

# %%
t3 = filter(lambda str:str != '', t2)

# %%
words = re.split(r'\s|\,|\.|\(|\)', t1.lower())
count = Counter(words)

# %%
count
# Out:
# Counter({'': 315,
#          '!': 4,
#          '!!': 1,
#          '#': 1,
#          '*': 1,
#          '10': 1,
#          '1000': 17,
#          '10000': 58,
#          '10周年': 1,
#          '122': 1,
#          '18禁': 1,
#          '2': 3,
#          '20000': 9,
#          '2017': 1,
#          '2b': 1,
#          '3': 1,
#          '30000': 1,
#          '3周年': 1,
#          '4': 1,
#          '5000': 99,
#          '7500': 1,
#          '7日': 1,
#          '93': 9,
#          '95': 2,
#          ':': 1,
#          '_': 7,
#          'a': 3,
#          'ahri': 2,
#          'azurlane': 1,
#          'c': 10,
#          'clamp': 1,
#          'clipstudiopaint': 9,
#          'collection': 1,
#          'cv': 1,
#          'did': 1,
#          'dress': 1,
#          'fantasy': 2,
#          'fate': 47,
#          'fate/apocrypha': 8,
#          'fate/extella': 2,
#          'fate/extra': 2,
#          'fate/go': 69,
#          'fate/grandorder': 69,
#          'fate/kaleidliner': 1,
#          'fate/kancolle': 1,
#          'fate/staynight': 4,
#          'fate/zero': 1,
#          'fatego': 1,
#          'ff': 3,
#          'ff14': 2,
#          'fgo': 40,
#          'finalfantasy': 1,
#          'five': 1,
#          'gremory': 1,
#          'hero': 2,
#          'highschooldxd': 1,
#          'hq': 1,
#          'in': 2,
#          'jk': 1,
#          'k2': 1,
#          'kenzen': 1,
#          'lavenderquartz': 1,
#          'league': 2,
#          'legends': 2,
#          'lol': 1,
#          'm3': 1,
#          'mf文庫j': 1,
#          'miku': 2,
#          'nier': 3,
#          'nier:automata': 3,
#          'of': 2,
#          'pixiv': 1,
#          'qys': 1,
#          'r': 1,
#          'r18': 1,
#          're:ゼロから始める異世界生活': 2,
#          'rias': 1,
#          'seven': 1,
#          'sona': 1,
#          'starguardian': 1,
#          'sukja': 1,
#          'tifa': 1,
#          'tバック': 1,
#          'users': 185,
#          'v': 1,
#          'vocaloid': 13,
#          'vライン': 1,
#          'wlop': 1,
#          '…': 1,
#          'ⅱ': 2,
#          '、': 1,
#          '〔': 2,
#          '〕': 2,
#          'いい': 2,
#          'いいね!': 1,
#          'いく': 1,
#          'いぶ': 2,
#          'う': 1,
#          'お': 10,
#          'おかっぱ': 1,
#          'おさげ': 1,
#          'おしり': 1,
#          'おっぱい': 19,
#          'おねショタ': 1,
#          'お幸せ': 1,
#          'お腹': 3,
#          'か': 2,
#          'かきあげ': 1,
#          'かけ': 1,
#          'かっこいい': 1,
#          'かわいい': 8,
#          'が': 3,
#          'ぐだ': 1,
#          'こっち': 1,
#          'これ': 8,
#          'これはいい': 1,
#          'ご': 1,
#          'さ': 3,
#          'さん': 2,
#          'し': 1,
#          'しない': 2,
#          'しろ': 1,
#          'すぎる': 10,
#          'ぜ': 1,
#          'そう': 2,
#          'た': 4,
#          'たい': 13,
#          'たくしあげ': 1,
#          'だ': 3,
#          'ち': 1,
#          'ちゃん': 1,
#          'ちょっと': 1,
#          'つけ': 1,
#          'つまむ': 1,
#          'て': 5,
#          'てる': 1,
#          'で': 6,
#          'です': 3,
#          'と': 6,
#          'な': 3,
#          'ない': 3,
#          'なかっ': 1,
#          'ながら': 2,
#          'なに': 5,
#          'なる': 1,
#          'に': 3,
#          'ねじ込': 2,
#          'ねじ込み': 1,
#          'の': 66,
#          'は': 4,
#          'はいてない': 1,
#          'ぱっくり': 1,
#          'ひな': 1,
#          'ふつくしい': 13,
#          'ふと': 16,
#          'へ': 1,
#          'へそ': 9,
#          'ぺたん': 1,
#          'ぼく': 5,
#          'まったく': 1,
#          'まどか☆マギカ': 1,
#          'まま': 2,
#          'みたい': 2,
#          'みよ': 1,
#          'みんな': 1,
#          'むちむち': 1,
#          'もう': 3,
#          'もも': 16,
#          'もらい': 2,
#          'や': 3,
#          'ゆ': 2,
#          'ゆきな': 1,
#          'ら': 1,
#          'る': 1,
#          'れ': 3,
#          'ろ': 5,
#          'を': 5,
#          'ん': 1,
#          'アイドルマスターシンデレラガールズ': 2,
#          'アイマス': 1,
#          'アガルタ': 1,
#          'アサシン': 1,
#          'アスデオ': 1,
#          'アストルフォ': 3,
#          'アズールレーン': 37,
#          'アップ': 1,
#          'アヒル隊長': 1,
#          'アビゲイル・ウィリアムズ': 1,
#          'アルテラ': 5,
#          'アルテラ・ザ・サン': 1,
#          'アルトリア': 5,
#          'アルトリア・ペンドラゴン': 1,
#          'アンクレット': 1,
#          'アンダーリム': 1,
#          'アーチャー': 3,
#          'イシュタル': 3,
#          'イシュミール': 1,
#          'イスカンダル': 1,
#          'イベント': 2,
#          'イヤホン': 2,
#          'イラストリアス': 2,
#          'イリヤ': 2,
#          'イリヤスフィール・フォン・アインツベルン': 2,
#          'イルミネーション': 1,
#          'インフェルノ': 3,
#          'ウェイバー': 1,
#          'ウェディングドレス': 1,
#          'ウォッシュ': 1,
#          'ウォースパイト': 1,
#          'エアリアル': 1,
#          'エドモン・ダンテス': 1,
#          'エミヤ': 1,
#          'エルキドゥ': 1,
#          'エレシュキガル': 4,
#          'エロ': 2,
#          'エーデル': 2,
#          'オイル': 1,
#          'オジネフェ': 1,
#          'オジマンディアス': 2,
#          'オッドアイ': 1,
#          'オナニー': 1,
#          'オフショルダー': 2,
#          'オリジナル': 96,
#          'オルタ': 5,
#          'オーナメント': 1,
#          'オーバーラップ文庫': 1,
#          'カチューシャ': 1,
#          'カットアウェイショルダー': 1,
#          'カフェ': 1,
#          'カルデア': 1,
#          'カルナ': 2,
#          'カヴァス': 1,
#          'カードキャプターさくら': 2,
#          'ガラス': 1,
#          'ガーターベルト': 2,
#          'ガーターリング': 2,
#          'キャス': 2,
#          'キャスケット': 1,
#          'キャスター': 1,
#          'キャメロット': 1,
#          'キュンキュン': 1,
#          'ギルガメッシュ': 3,
#          'クイーン・エリザベス': 1,
#          'クマ': 1,
#          'クラウディウス': 2,
#          'クリスマス': 3,
#          'クリック': 7,
#          'クリーブランド': 1,
#          'クリームソーダ': 1,
#          'クロエ・フォン・アインツベルン': 1,
#          'クロッチ': 1,
#          'グラブル': 1,
#          'グランドピアノ': 1,
#          'グランブルーファンタジー': 1,
#          'グラーフ・ツェッペリン': 2,
#          'ケツ': 1,
#          'ケーブル': 1,
#          'ゲシュタポ': 1,
#          'コス': 1,
#          'コミティア': 1,
#          'コンビ': 1,
#          'コート': 1,
#          'サイ': 1,
#          'サマー': 1,
#          'サムライ': 1,
#          'サラミ': 1,
#          'サン': 1,
#          'サングラス': 1,
#          'サンタ': 1,
#          'サンバイザー': 1,
#          'ザ・サン': 1,
#          'シャフ度': 1,
#          'シュヴァリエ・デオン': 1,
#          'ショートブーツ': 1,
#          'シリーズ': 2,
#          'シースルー': 1,
#          'シールダー': 1,
#          'ジャンヌ・オルタ': 5,
#          'ジャンヌ・ダルク': 4,
#          'スカサハ': 4,
#          'スカラ': 1,
#          'スカートめくり': 1,
#          'スキー': 1,
#          'スケブラ': 1,
#          'スタジャン': 1,
#          'ストッキング': 2,
#          'スノードーム': 1,
#          'セイバー': 5,
#          'セイバーオルタ': 5,
#          'セイバー・リリィ': 1,
#          'セイレム': 1,
#          'セクシー': 2,
#          'セミロング': 1,
#          'セーター': 1,
#          'セーラー服': 2,
#          'ゼロ': 3,
#          'ソックス': 1,
#          'タ': 2,
#          'タイツ': 5,
#          'タイトスカート': 1,
#          'タレ目': 1,
#          'タートルネック': 1,
#          'ダイヤ': 1,
#          'ダイヤモンド': 4,
#          'ダッフルコート': 1,
#          'ダ・ヴィンチちゃん': 1,
#          'ダークファンタジー': 1,
#          'チェンジ': 1,
#          'チョーカー': 1,
#          'チラ': 1,
#          'ツイン': 1,
#          'ツインテール': 2,
#          'ツーサイドアップ': 1,
#          'ティファ': 1,
#          'ティファ・ロックハート': 1,
#          'テラ': 1,
#          'テライケメン': 1,
#          'デッドヒート': 1,
#          'デレマス': 1,
#          'デンジャラス・ビースト': 3,
#          'トア': 1,
#          'トランク': 1,
#          'トリック・オア・トリート': 3,
#          'ドm': 1,
#          'ドスケベ': 1,
#          'ドライブ': 1,
#          'ドリル': 1,
#          'ナイチンゲール': 3,
#          'ニット': 1,
#          'ニットワンピ': 1,
#          'ニラ': 1,
#          'ニー': 2,
#          'ニーアオートマタ': 3,
#          'ニーソ': 1,
#          'ニーソックス': 2,
#          'ニート': 2,
#          'ヌード': 2,
#          'ネロ': 2,
#          'ノスフィー': 1,
#          'ノッブ': 1,
#          'ハイ': 1,
#          'ハイキュー!!': 1,
#          'ハイスクールd×d': 2,
#          'ハイセンス': 1,
#          'ハイソックス': 2,
#          'ハイタッチ': 1,
#          'ハイビスカス': 1,
#          'ハイレグ': 1,
#          'ハロウィン': 3,
#          'ハーミーズ': 1,
#          'バカップル': 1,
#          'ババア結婚してくれ': 1,
#          'バラ': 1,
#          'バンザイ': 1,
#          'バーサー': 3,
#          'バーサーカー': 1,
#          'パン': 2,
#          'パンスト': 1,
#          'パンダ': 1,
#          'パンツ': 12,
#          'ビキニ': 2,
#          'ピアス': 3,
#          'ピアノ': 1,
#          'ピクシブたん': 2,
#          'ピッカピカ': 1,
#          'ピンク': 1,
#          'ピース': 1,
#          'ファイナルファンタジー14': 2,
#          'ファンタジー': 1,
#          'フィニス・カルデア': 1,
#          'フェルト': 2,
#          'フォスフォフィライト': 1,
#          'フラグメンツ': 1,
#          'フランケンシュタイン': 6,
#          'フレイム': 1,
#          'ブラ': 3,
#          'ブレスレット': 1,
#          'プリケツ': 2,
#          'プリズマ': 1,
#          'プリズマ☆イリヤ': 10,
#          'プリンツ・オイゲン': 2,
#          'プロの犯行': 1,
#          'ベビードール': 1,
#          'ベレー帽': 1,
#          'ホイホイ': 1,
#          'ホモ': 1,
#          'ホルターネック': 1,
#          'ホルタービキニ': 1,
#          'ボブカット': 5,
#          'ボルツ': 1,
#          'ポトフ': 1,
#          'ポニーテール': 2,
#          'ポーズ': 1,
#          'マギアレコード': 2,
#          'マシュ・キリエライト': 3,
#          'マジ': 1,
#          'マニキュア': 3,
#          'マフラー': 2,
#          'マリー・アントワネット': 7,
#          'マルタ': 1,
#          'マレ': 1,
#          'マン': 1,
#          'マーリン': 2,
#          'ミク': 1,
#          'ミコッテ': 2,
#          'ムートンブーツ': 1,
#          'メイド': 3,
#          'メイド服': 2,
#          'メイヴ': 5,
#          'メソポタミア': 1,
#          'メドゥーサ': 1,
#          'メント': 1,
#          'モーアス': 1,
#          'モードレッド': 2,
#          'ヤンデレ': 1,
#          'ヨルハ2号b型': 1,
#          'ヨルハa型二号': 2,
#          'ライダー': 3,
#          'ラブライブ!': 2,
#          'ラブライブ!サンシャイン!!': 2,
#          'リ': 3,
#          'リアス・グレモリー': 1,
#          'リゼロ': 2,
#          'リブ': 1,
#          'レイプ目': 1,
#          'レズールアーン': 1,
#          'レム': 4,
#          'レース': 1,
#          'レースクイーン': 1,
#          'ロケット': 1,
#          'ロマニ・アーキマン': 1,
#          'ロリコン': 2,
#          'ロング': 7,
#          'ロングスカート': 1,
#          'ロングヘアー': 7,
#          'ロード・エルメロイ': 1,
#          'ローファー': 1,
#          'ワダアルコ': 2,
#          'ワトラ': 1,
#          'ワンサイド': 1,
#          'ワンピース': 2,
#          'ワンレングス': 1,
#          'ヴァルキリー': 1,
#          '・': 14,
#          '一ノ瀬志希': 1,
#          '一切': 1,
#          '一航戦': 1,
#          '七夕': 1,
#          '七番': 1,
#          '三つ': 2,
#          '上がり': 1,
#          '下ろし': 2,
#          '下乳': 2,
#          '下着': 2,
#          '丑': 1,
#          '世': 2,
#          '両': 1,
#          '丢人': 1,
#          '之': 1,
#          '乙女': 1,
#          '乳': 7,
#          '二': 1,
#          '人': 1,
#          '仕事': 3,
#          '仮装': 1,
#          '仰臥': 3,
#          '伏臥': 1,
#          '佐野徹夜': 1,
#          '例': 1,
#          '例の紐': 1,
#          '保障': 1,
#          '光': 1,
#          '光の三原色': 1,
#          '入り': 185,
#          '全て': 1,
#          '全裸': 1,
#          '内': 1,
#          '円卓': 2,
#          '円卓の騎士': 1,
#          '冬': 1,
#          '创': 1,
#          '初音ミク': 8,
#          '制服': 4,
#          '前': 7,
#          '前線': 11,
#          '剣': 1,
#          '剣豪': 1,
#          '剥ぎ': 3,
#          '創作': 7,
#          '加': 1,
#          '加藤段蔵': 1,
#          '加賀': 2,
#          '勝てる': 2,
#          '勝利': 1,
#          '勝負': 1,
#          '十': 1,
#          '十咎ももこ': 1,
#          '千': 3,
#          '半': 1,
#          '博麗霊夢': 1,
#          '原': 1,
#          '取り': 3,
#          '叛逆': 1,
#          '口紅': 1,
#          '右上': 1,
#          '吟遊詩人': 1,
#          '和服': 2,
#          '咎': 1,
#          '唇': 1,
#          '回し': 3,
#          '型': 3,
#          '埋め': 2,
#          '夕立': 2,
#          '夜': 3,
#          '夜明け': 1,
#          '大剣': 1,
#          '大天使': 1,
#          '大学生': 2,
#          '大道寺知世': 1,
#          '天': 1,
#          '天使': 1,
#          '太腿': 1,
#          '失敗': 2,
#          '女': 6,
#          '女の子': 35,
#          '女体': 5,
#          '女子大生': 2,
#          '女子高生': 3,
#          '女神': 3,
#          '妖': 1,
#          '妖艶': 1,
#          '妹': 1,
#          '姉': 1,
#          '姉さん': 1,
#          '姐': 1,
#          '姫': 1,
#          '姿': 2,
#          '娘': 9,
#          '嫌': 4,
#          '子': 3,
#          '存在感': 2,
#          '安産': 2,
#          '宝石の国': 11,
#          '宮本武蔵': 2,
#          '富士見': 1,
#          '寝そべり': 1,
#          '寿司': 1,
#          '射': 2,
#          '小': 1,
#          '小原鞠莉': 1,
#          '小説家になろう': 2,
#          '少女': 25,
#          '尻': 25,
#          '島村卯月': 1,
#          '崩壊': 1,
#          '川原': 1,
#          '巨乳': 5,
#          '巫女': 2,
#          '希望': 1,
#          '年上彼女': 1,
#          '幼なじみ': 1,
#          '幼馴染': 2,
#          '幽々子': 1,
#          '座り': 1,
#          '廃墟': 1,
#          '式': 2,
#          '彼女': 1,
#          '後ろ': 1,
#          '御前': 1,
#          '徳利': 1,
#          '恍惚': 1,
#          '悪性': 1,
#          '愛': 1,
#          '愛宕': 4,
#          '感': 2,
#          '我々': 1,
#          '我が': 1,
#          '战舰': 1,
#          '戦艦': 2,
#          '投下': 1,
#          '拷問': 1,
#          '指': 2,
#          '振袖': 1,
#          '推奨': 7,
#          '撫で': 3,
#          '改': 1,
#          '新宿': 2,
#          '施し': 1,
#          '旅': 1,
#          '映り': 1,
#          '時雨': 3,
#          '暁星': 1,
#          '最強': 1,
#          '最高': 1,
#          '朔月美遊': 1,
#          '朝焼け': 1,
#          '木之本桜': 1,
#          '本家': 1,
#          '本棚': 1,
#          '朱': 1,
#          '東方': 3,
#          '東方project': 3,
#          '柚原': 1,
#          '柴犬': 1,
#          '桃子': 1,
#          '椿': 1,
#          '業界': 1,
#          '極上': 10,
#          '楽園': 1,
#          '概念': 2,
#          '様': 1,
#          '横乳': 5,
#          '横臥': 1,
#          '機関': 1,
#          '櫂人': 1,
#          '正座': 1,
#          '歩く': 1,
#          '殺戮': 1,
#          '気': 2,
#          '水中': 1,
#          '水滴': 1,
#          '水着': 15,
#          '永': 1,
#          '法官': 1,
#          '泡沫': 1,
#          '波打ち際': 2,
#          '泣き': 1,
#          '泣ける': 1,
#          '津島善子': 1,
#          '浴衣': 2,
#          '涙腺': 1,
#          '清': 1,
#          '清姫': 1,
#          '清涼感': 2,
#          '渡辺曜': 1,
#          '温泉': 1,
#          '源頼光': 2,
#          '漫画': 5,
#          '澪': 1,
#          '瀬名': 1,
#          '無言': 2,
#          '爆了': 2,
#          '父': 1,
#          '片想い': 1,
#          '片目': 1,
#          '片足': 1,
#          '犬': 2,
#          '狐': 4,
#          '狼': 1,
#          '猫': 3,
#          '玉藻': 2,
#          '王': 1,
#          '理': 1,
#          '理想郷': 1,
#          '生まれ': 1,
#          '生地': 1,
#          '生誕祭': 1,
#          '産まれ': 1,
#          '甲冑': 1,
#          '男': 4,
#          '男女': 5,
#          '異世界拷問姫': 1,
#          '異世界迷宮の最深部を目指そう': 1,
#          '異形': 1,
#          '異端': 1,
#          '白': 1,
#          '白タイツ': 2,
#          '白ワンピ': 1,
#          '白髪': 1,
#          '百合': 3,
#          '的': 2,
#          '監獄': 2,
#          '眼鏡': 1,
#          '眼鏡っ娘': 2,
#          '着物': 3,
#          '着衣': 1,
#          '瞑目': 1,
#          '碧': 6,
#          '磯風': 1,
#          '礼装': 5,
#          '神': 1,
#          '神様': 20,
#          '神聖': 1,
#          '私服': 3,
#          '秋': 1,
#          '秋風': 1,
#          '空': 1,
#          '突っ込み': 2,
#          '窓': 2,
#          '竜': 1,
#          '竞技': 1,
#          '童貞': 1,
#          '競泳水着': 1,
#          '等': 1,
#          '米': 1,
#          '粛清': 1,
#          '約束': 1,
#          '紅葉': 1,
#          '紐': 1,
#          '素敵': 2,
#          '素晴': 1,
#          '素晴らし': 9,
#          '索': 1,
#          '組': 2,
#          '組み': 1,
#          '結婚': 1,
#          '絵': 3,
#          '絶対': 1,
#          '継続': 1,
#          '緊縛': 1,
#          '緑': 1,
#          '編み': 2,
#          '織田信勝': 2,
#          '織田信長': 5,
#          '线': 11,
#          '美し': 1,
#          '美しい': 1,
#          '美乳': 1,
#          '美女': 1,
#          '美少女': 2,
#          '美少年': 1,
#          '美遊': 2,
#          '翔鶴': 2,
#          '翼': 1,
#          '者': 1,
#          '耳': 3,
#          '耳かき': 1,
#          '联盟': 2,
#          '聖': 1,
#          '聖処女': 1,
#          '股間': 2,
#          '背中': 1,
#          '背景': 3,
#          '胸ポチ': 1,
#          '脇': 1,
#          '脱ぎ': 1,
#          '腋': 5,
#          '腕時計': 1,
#          '腹': 1,
#          '航空機': 1,
#          '舰队': 1,
#          '艦': 6,
#          '艦これ': 12,
#          '艦船': 3,
#          '艦隊これくしょん': 6,
#          '良妻賢母': 1,
#          '艶': 3,
#          '花': 1,
#          '花柄': 1,
#          '英雄': 3,
#          '英霊': 1,
#          '茅野愛衣': 1,
#          '茶会': 1,
#          '茶髪': 1,
#          '荒ぶ': 1,
#          '落書き': 1,
#          '蓝航': 6,
#          '薔薇': 1,
#          '藤丸立香': 1,
#          '螺旋階段': 1,
#          '街並み': 1,
#          '衛宮士郎': 1,
#          '衣': 1,
#          '衣装': 4,
#          '袋': 4,
#          '被衣': 1,
#          '袴': 1,
#          '装備': 1,
#          '裏': 4,
#          '裸足': 7,
#          '裾': 1,
#          '褐色': 1,
#          '褒美': 1,
#          '西行': 1,
#          '西行寺幽々子': 1,
#          '見せ': 2,
#          '角': 1,
#          '許さ': 1,
#          '誘っ': 1,
#          '謎': 1,
#          '谷間': 12,
#          '貴': 1,
#          '賢': 1,
#          '贺': 1,
#          '赤': 1,
#          '赤城': 2,
#          '超': 1,
#          '越し': 3,
#          '足': 3,
#          '足指': 1,
#          '輪': 1,
#          '込み': 1,
#          '远的': 1,
#          '逆流': 1,
#          '透けブラ': 1,
#          '透明': 2,
#          '過去': 1,
#          '遠き': 1,
#          '遠坂凛': 3,
#          '都': 1,
#          '重巡': 1,
#          '金木犀': 1,
#          '金髪': 1,
#          '金魚': 1,
#          '鈴': 1,
#          '鈴谷': 1,
#          '鉄橋': 1,
#          '銀河': 2,
#          '銀髪': 1,
#          '鎖骨': 1,
#          '長': 2,
#          '長手': 4,
#          '間桐桜': 1,
#          '降雪': 1,
#          '限定': 3,
#          '隔絶': 1,
#          '隠れ': 1,
#          '雨傘': 1,
#          '雪': 1,
#          '電車': 1,
#          '霊夢': 1,
#          '霞ヶ丘詩羽': 1,
#          '露天風呂': 2,
#          '青': 1,
#          '青髪': 1,
#          '鞭': 3,
#          '音楽': 1,
#          '領域': 1,
#          '顔': 4,
#          '風呂': 1,
#          '風景': 3,
#          '食べ物': 1,
#          '駆逐': 1,
#          '駆逐艦': 1,
#          '高品質': 1,
#          '高山箕犀': 2,
#          '高雄': 2,
#          '髪': 2,
#          '髪ブラ': 1,
#          '魅惑': 25,
#          '魔境': 1,
#          '魔女': 1,
#          '魔法': 1,
#          '魚': 1,
#          '鹭咲': 1,
#          '麗しき': 1,
#          '黒': 5,
#          '黒縄地獄': 1,
#          '黒髪': 7,
#          '鼠蹊部': 2,
#          '소녀전선': 1,
#          '･': 1})

# %%
for word, cnt in count.most_common(21):
    print(word)
    #print(cnt)
# Out:
# users
# 入り
# 5000
# オリジナル
# fate/grandorder
# fate/go
# の
# 10000
# fate
# fgo
# アズールレーン
# 女の子
# 尻
# 魅惑
# 少女
# 神様
# おっぱい
# 1000
# ふと
# もも
